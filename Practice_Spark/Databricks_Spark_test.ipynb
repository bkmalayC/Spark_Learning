# %%
from pyspark.sql.functions import lit
df = spark.createDataFrame([("Hello Spark", "Lets learn")], ["Column1", "Column2"])
df = df.withColumn("Column3", lit("Gen AI"))
# Data will be shown in tabular format using display()

# Data will be shown in tabular format using display(), which renders a bordered table in Databricks notebooks by default
df.show()
