# %%
uploaded_file = "/Volumes/workspace/Default/dbfs/flattened_output.xlsx"  # Set this widget in the UI or use dbutils.widgets.text
import os
file_size = os.path.getsize(uploaded_file)
print(f"Uploaded file size: {file_size} bytes")
print("File uploaded successfully")
# If running interactively, you can use the Databricks sidebar "Upload Data" button to upload your file to /dbfs/FileStore/
# Example: After uploading, set uploaded_file = "/dbfs/FileStore/path/to/your_file.xlsx"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 uploaded_file = "/Volumes/workspace/Default/dbfs/flattened_output.xlsx"  # Set this widget in the UI or use dbutils.widgets.text
#       2 import os
# ----> 3 file_size = os.path.getsize(uploaded_file)
#       4 print(f"Uploaded file size: {file_size} bytes")
#       5 print("File uploaded successfully")
#
# File <frozen genericpath>:86, in getsize(filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/Volumes/workspace/Default/dbfs/flattened_output.xlsx'
